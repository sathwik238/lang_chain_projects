# %%
# pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-1.0.3-cp39-abi3-win_amd64.whl.metadata (7.0 kB)
# Collecting build>=1.0.3 (from chromadb)
#   Using cached build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: pydantic>=1.9 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (2.10.6)
# Collecting chroma-hnswlib==0.7.6 (from chromadb)
#   Using cached chroma_hnswlib-0.7.6-cp310-cp310-win_amd64.whl.metadata (262 bytes)
# Collecting fastapi==0.115.9 (from chromadb)
#   Downloading fastapi-0.115.9-py3-none-any.whl.metadata (27 kB)
# Collecting uvicorn>=0.18.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: numpy>=1.22.5 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (1.26.4)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.23.0-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (4.12.2)
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.21.0-cp310-cp310-win_amd64.whl.metadata (4.9 kB)
# Collecting opentelemetry-api>=1.2.0 (from chromadb)
#   Downloading opentelemetry_api-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Collecting opentelemetry-exporter-otlp-proto-grpc>=1.2.0 (from chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-instrumentation-fastapi>=0.41b0 (from chromadb)
#   Downloading opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl.metadata (2.2 kB)
# Collecting opentelemetry-sdk>=1.2.0 (from chromadb)
#   Downloading opentelemetry_sdk-1.31.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: tokenizers>=0.13.2 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (0.21.0)
# Collecting pypika>=0.48.9 (from chromadb)
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: tqdm>=4.65.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (4.67.1)
# Collecting overrides>=7.3.1 (from chromadb)
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting importlib-resources (from chromadb)
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: grpcio>=1.58.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (1.71.0rc2)
# Collecting bcrypt>=4.0.1 (from chromadb)
#   Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Collecting typer>=0.9.0 (from chromadb)
#   Downloading typer-0.15.2-py3-none-any.whl.metadata (15 kB)
# Collecting kubernetes>=28.1.0 (from chromadb)
#   Downloading kubernetes-32.0.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: tenacity>=8.2.3 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: pyyaml>=6.0.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (6.0.2)
# Collecting mmh3>=4.0.1 (from chromadb)
#   Using cached mmh3-5.1.0-cp310-cp310-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: orjson>=3.9.12 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (3.10.15)
# Requirement already satisfied: httpx>=0.27.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: jsonschema>=4.19.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from chromadb) (4.23.0)
# Collecting starlette<0.46.0,>=0.40.0 (from fastapi==0.115.9->chromadb)
#   Using cached starlette-0.45.3-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=19.1 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from build>=1.0.3->chromadb) (24.2)
# Collecting pyproject_hooks (from build>=1.0.3->chromadb)
#   Using cached pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: colorama in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from build>=1.0.3->chromadb) (0.4.6)
# Collecting importlib-metadata>=4.6 (from build>=1.0.3->chromadb)
#   Using cached importlib_metadata-8.6.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting tomli>=1.1.0 (from build>=1.0.3->chromadb)
#   Using cached tomli-2.2.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: anyio in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (4.8.0)
# Requirement already satisfied: certifi in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from httpx>=0.27.0->chromadb) (3.10)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from jsonschema>=4.19.0->chromadb) (0.23.1)
# Requirement already satisfied: six>=1.9.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.9.0.post0)
# Requirement already satisfied: google-auth>=1.0.1 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.38.0)
# Collecting websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 (from kubernetes>=28.1.0->chromadb)
#   Using cached websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: requests in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.32.3)
# Collecting requests-oauthlib (from kubernetes>=28.1.0->chromadb)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes>=28.1.0->chromadb)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: urllib3>=1.24.2 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from kubernetes>=28.1.0->chromadb) (2.3.0)
# Collecting durationpy>=0.7 (from kubernetes>=28.1.0->chromadb)
#   Using cached durationpy-0.9-py3-none-any.whl.metadata (338 bytes)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl.metadata (12 kB)
# Collecting flatbuffers (from onnxruntime>=1.14.1->chromadb)
#   Downloading flatbuffers-25.2.10-py2.py3-none-any.whl.metadata (875 bytes)
# Requirement already satisfied: protobuf in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.3)
# Requirement already satisfied: sympy in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from onnxruntime>=1.14.1->chromadb) (1.13.1)
# Collecting deprecated>=1.2.6 (from opentelemetry-api>=1.2.0->chromadb)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: googleapis-common-protos~=1.52 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.68.0)
# Collecting opentelemetry-exporter-otlp-proto-common==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl.metadata (1.9 kB)
# Collecting opentelemetry-proto==1.31.1 (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb)
#   Downloading opentelemetry_proto-1.31.1-py3-none-any.whl.metadata (2.4 kB)
# Collecting opentelemetry-instrumentation-asgi==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl.metadata (2.1 kB)
# Collecting opentelemetry-instrumentation==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_instrumentation-0.52b1-py3-none-any.whl.metadata (6.8 kB)
# Collecting opentelemetry-semantic-conventions==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl.metadata (2.5 kB)
# Collecting opentelemetry-util-http==0.52b1 (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Downloading opentelemetry_util_http-0.52b1-py3-none-any.whl.metadata (2.6 kB)
# Collecting wrapt<2.0.0,>=1.0.0 (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached wrapt-1.17.2-cp310-cp310-win_amd64.whl.metadata (6.5 kB)
# Collecting asgiref~=3.0 (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb)
#   Using cached asgiref-3.8.1-py3-none-any.whl.metadata (9.3 kB)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting backoff>=1.10.0 (from posthog>=2.4.0->chromadb)
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: distro>=1.5.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from pydantic>=1.9->chromadb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from pydantic>=1.9->chromadb) (2.27.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from rich>=10.11.0->chromadb) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from rich>=10.11.0->chromadb) (2.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from tokenizers>=0.13.2->chromadb) (0.29.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from typer>=0.9.0->chromadb) (8.1.8)
# Collecting shellingham>=1.3.0 (from typer>=0.9.0->chromadb)
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting httptools>=0.6.3 (from uvicorn[standard]>=0.18.3->chromadb)
#   Using cached httptools-0.6.4-cp310-cp310-win_amd64.whl.metadata (3.7 kB)
# Requirement already satisfied: python-dotenv>=0.13 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.1)
# Collecting watchfiles>=0.13 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading watchfiles-1.0.5-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Collecting websockets>=10.4 (from uvicorn[standard]>=0.18.3->chromadb)
#   Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: filelock in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers>=0.13.2->chromadb) (2025.2.0)
# Collecting zipp>=3.20 (from importlib-metadata>=4.6->build>=1.0.3->chromadb)
#   Using cached zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: mdurl~=0.1 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from requests->kubernetes>=28.1.0->chromadb) (3.4.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from anyio->httpx>=0.27.0->chromadb) (1.3.1)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Using cached pyreadline3-3.5.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\sathw\desktop\ml\llm\lang chain campus x\lang_chain_projects\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.6.1)
# Downloading chromadb-1.0.3-cp39-abi3-win_amd64.whl (18.2 MB)
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.2 MB 1.3 MB/s eta 0:00:14
#    - -------------------------------------- 0.8/18.2 MB 1.1 MB/s eta 0:00:17
#    - -------------------------------------- 0.8/18.2 MB 1.1 MB/s eta 0:00:17
#    -- ------------------------------------- 1.3/18.2 MB 1.1 MB/s eta 0:00:16
#    --- ------------------------------------ 1.6/18.2 MB 1.1 MB/s eta 0:00:15
#    ---- ----------------------------------- 1.8/18.2 MB 1.2 MB/s eta 0:00:14
#    ---- ----------------------------------- 2.1/18.2 MB 1.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 2.4/18.2 MB 1.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 2.4/18.2 MB 1.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 2.6/18.2 MB 1.1 MB/s eta 0:00:15
#    ------ --------------------------------- 2.9/18.2 MB 1.1 MB/s eta 0:00:15
#    ------- -------------------------------- 3.4/18.2 MB 1.2 MB/s eta 0:00:13
#    -------- ------------------------------- 3.7/18.2 MB 1.2 MB/s eta 0:00:13
#    -------- ------------------------------- 3.9/18.2 MB 1.2 MB/s eta 0:00:12
#    --------- ------------------------------ 4.2/18.2 MB 1.2 MB/s eta 0:00:12
#    --------- ------------------------------ 4.5/18.2 MB 1.2 MB/s eta 0:00:12
#    ---------- ----------------------------- 4.7/18.2 MB 1.2 MB/s eta 0:00:12
#    ---------- ----------------------------- 5.0/18.2 MB 1.2 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.2/18.2 MB 1.2 MB/s eta 0:00:11
#    ------------ --------------------------- 5.5/18.2 MB 1.2 MB/s eta 0:00:11
#    ------------- -------------------------- 6.0/18.2 MB 1.2 MB/s eta 0:00:10
#    ------------- -------------------------- 6.3/18.2 MB 1.3 MB/s eta 0:00:10
#    -------------- ------------------------- 6.8/18.2 MB 1.3 MB/s eta 0:00:09
#    ---------------- ----------------------- 7.3/18.2 MB 1.4 MB/s eta 0:00:09
#    ----------------- ---------------------- 8.1/18.2 MB 1.4 MB/s eta 0:00:08
#    ------------------ --------------------- 8.7/18.2 MB 1.5 MB/s eta 0:00:07
#    -------------------- ------------------- 9.2/18.2 MB 1.5 MB/s eta 0:00:07
#    --------------------- ------------------ 9.7/18.2 MB 1.5 MB/s eta 0:00:06
#    ---------------------- ----------------- 10.2/18.2 MB 1.6 MB/s eta 0:00:06
#    ----------------------- ---------------- 10.7/18.2 MB 1.6 MB/s eta 0:00:05
#    ------------------------ --------------- 11.3/18.2 MB 1.6 MB/s eta 0:00:05
#    ------------------------- -------------- 11.8/18.2 MB 1.7 MB/s eta 0:00:04
#    --------------------------- ------------ 12.6/18.2 MB 1.7 MB/s eta 0:00:04
#    ----------------------------- ---------- 13.4/18.2 MB 1.8 MB/s eta 0:00:03
#    ------------------------------ --------- 13.9/18.2 MB 1.8 MB/s eta 0:00:03
#    ------------------------------- -------- 14.4/18.2 MB 1.8 MB/s eta 0:00:03
#    --------------------------------- ------ 15.5/18.2 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 16.0/18.2 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 16.3/18.2 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------- -- 17.0/18.2 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------  17.8/18.2 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 18.2/18.2 MB 2.0 MB/s eta 0:00:00
# Using cached chroma_hnswlib-0.7.6-cp310-cp310-win_amd64.whl (150 kB)
# Downloading fastapi-0.115.9-py3-none-any.whl (94 kB)
# Downloading bcrypt-4.3.0-cp39-abi3-win_amd64.whl (152 kB)
# Using cached build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading kubernetes-32.0.1-py2.py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 3.3 MB/s eta 0:00:01
#    ------------------------------- -------- 1.6/2.0 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 3.5 MB/s eta 0:00:00
# Using cached mmh3-5.1.0-cp310-cp310-win_amd64.whl (41 kB)
# Downloading onnxruntime-1.21.0-cp310-cp310-win_amd64.whl (11.8 MB)
#    ---------------------------------------- 0.0/11.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.8 MB 4.2 MB/s eta 0:00:03
#    -------- ------------------------------- 2.6/11.8 MB 6.9 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.4/11.8 MB 6.3 MB/s eta 0:00:02
#    ---------------- ----------------------- 4.7/11.8 MB 5.9 MB/s eta 0:00:02
#    ------------------- -------------------- 5.8/11.8 MB 5.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.1/11.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.4/11.8 MB 5.8 MB/s eta 0:00:01
#    -------------------------------- ------- 9.7/11.8 MB 6.0 MB/s eta 0:00:01
#    ------------------------------------ --- 10.7/11.8 MB 5.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.8/11.8 MB 5.6 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.31.1-py3-none-any.whl (65 kB)
# Downloading opentelemetry_exporter_otlp_proto_grpc-1.31.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_exporter_otlp_proto_common-1.31.1-py3-none-any.whl (18 kB)
# Downloading opentelemetry_proto-1.31.1-py3-none-any.whl (55 kB)
# Downloading opentelemetry_instrumentation_fastapi-0.52b1-py3-none-any.whl (12 kB)
# Downloading opentelemetry_instrumentation-0.52b1-py3-none-any.whl (31 kB)
# Downloading opentelemetry_instrumentation_asgi-0.52b1-py3-none-any.whl (16 kB)
# Downloading opentelemetry_semantic_conventions-0.52b1-py3-none-any.whl (183 kB)
# Downloading opentelemetry_util_http-0.52b1-py3-none-any.whl (7.3 kB)
# Downloading opentelemetry_sdk-1.31.1-py3-none-any.whl (118 kB)
# Using cached overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading posthog-3.23.0-py2.py3-none-any.whl (84 kB)
# Downloading typer-0.15.2-py3-none-any.whl (45 kB)
# Using cached uvicorn-0.34.0-py3-none-any.whl (62 kB)
# Using cached importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Using cached durationpy-0.9-py3-none-any.whl (3.5 kB)
# Using cached httptools-0.6.4-cp310-cp310-win_amd64.whl (88 kB)
# Using cached importlib_metadata-8.6.1-py3-none-any.whl (26 kB)
# Using cached monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Using cached starlette-0.45.3-py3-none-any.whl (71 kB)
# Using cached tomli-2.2.1-py3-none-any.whl (14 kB)
# Downloading watchfiles-1.0.5-cp310-cp310-win_amd64.whl (291 kB)
# Using cached websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading websockets-15.0.1-cp310-cp310-win_amd64.whl (176 kB)
# Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Downloading flatbuffers-25.2.10-py2.py3-none-any.whl (30 kB)
# Using cached pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Using cached asgiref-3.8.1-py3-none-any.whl (23 kB)
# Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Using cached wrapt-1.17.2-cp310-cp310-win_amd64.whl (38 kB)
# Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Using cached pyreadline3-3.5.4-py3-none-any.whl (83 kB)
# Installing collected packages: pypika, monotonic, flatbuffers, durationpy, zipp, wrapt, websockets, websocket-client, tomli, shellingham, pyreadline3, pyproject_hooks, overrides, opentelemetry-util-http, opentelemetry-proto, oauthlib, mmh3, importlib-resources, httptools, chroma-hnswlib, bcrypt, backoff, asgiref, watchfiles, uvicorn, starlette, requests-oauthlib, posthog, opentelemetry-exporter-otlp-proto-common, importlib-metadata, humanfriendly, deprecated, typer, opentelemetry-api, kubernetes, fastapi, coloredlogs, build, opentelemetry-semantic-conventions, onnxruntime, opentelemetry-sdk, opentelemetry-instrumentation, opentelemetry-instrumentation-asgi, opentelemetry-exporter-otlp-proto-grpc, opentelemetry-instrumentation-fastapi, chromadb
# Successfully installed asgiref-3.8.1 backoff-2.2.1 bcrypt-4.3.0 build-1.2.2.post1 chroma-hnswlib-0.7.6 chromadb-1.0.3 coloredlogs-15.0.1 deprecated-1.2.18 durationpy-0.9 fastapi-0.115.9 flatbuffers-25.2.10 httptools-0.6.4 humanfriendly-10.0 importlib-metadata-8.6.1 importlib-resources-6.5.2 kubernetes-32.0.1 mmh3-5.1.0 monotonic-1.6 oauthlib-3.2.2 onnxruntime-1.21.0 opentelemetry-api-1.31.1 opentelemetry-exporter-otlp-proto-common-1.31.1 opentelemetry-exporter-otlp-proto-grpc-1.31.1 opentelemetry-instrumentation-0.52b1 opentelemetry-instrumentation-asgi-0.52b1 opentelemetry-instrumentation-fastapi-0.52b1 opentelemetry-proto-1.31.1 opentelemetry-sdk-1.31.1 opentelemetry-semantic-conventions-0.52b1 opentelemetry-util-http-0.52b1 overrides-7.7.0 posthog-3.23.0 pypika-0.48.9 pyproject_hooks-1.2.0 pyreadline3-3.5.4 requests-oauthlib-2.0.0 shellingham-1.5.4 starlette-0.45.3 tomli-2.2.1 typer-0.15.2 uvicorn-0.34.0 watchfiles-1.0.5 websocket-client-1.8.0 websockets-15.0.1 wrapt-1.17.2 zipp-3.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain.schema import Document
from langchain_openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma

# %%
# create langchain document for iPL players
doc1 =    Document(page_content="Virat Kohli", metadata={"team": "RCB", "role": "Batsman"})
doc2 =    Document(page_content="MS Dhoni", metadata={"team": "CSK", "role": "Wicketkeeper"})
doc3 =    Document(page_content="Rohit Sharma", metadata={"team": "MI", "role": "Batsman"})
doc4 =    Document(page_content="Jasprit Bumrah", metadata={"team": "MI", "role": "Bowler"})
doc5 =    Document(page_content="Ravindra Jadeja", metadata={"team": "CSK", "role": "All-rounder"})
doc6 =    Document(page_content="AB de Villiers", metadata={"team": "RCB", "role": "Batsman"})
doc7 =    Document(page_content="David Warner", metadata={"team": "SRH", "role": "Batsman"})
doc8 =    Document(page_content="Kane Williamson", metadata={"team": "SRH", "role": "Batsman"})
doc9 =    Document(page_content="Ben Stokes", metadata={"team": "RR", "role": "All-rounder"})
doc10 = Document(page_content="Jos Buttler", metadata={"team": "RR", "role": "Wicketkeeper"})

# %%
vector_store = Chroma(embedding_function=OpenAIEmbeddings(), 
                    persist_directory="data/cheoma_db", 
                    collection_name="ipl_players")

# %%
vector_store.add_documents([doc1, doc2, doc3, doc4, doc5, doc6, doc7, doc8, doc9, doc10])
# Out:
# ['276d26b6-4604-48fc-bdde-fba38fb07970',
#  'f2e154d8-5b92-4381-9141-51b2ba6361f8',
#  '0b7d9b48-82b5-4fcc-b307-ec43ff2a03d8',
#  'dbb0e882-ce85-4489-999e-cb2e1e416fb8',
#  '95b3b8cc-010b-4e45-a276-6989290d2903',
#  '20d90905-a1e9-49b9-80d2-b189c39410ba',
#  'fa02260c-b111-40df-a613-a3822dc40423',
#  '70f64bd0-a763-43a4-ba4a-e591aed70aeb',
#  '4eb0e6b0-1690-4896-86ff-cdda95969989',
#  'e722182c-a5fd-4543-b719-80acc46e444f']

# %%
vector_store.get(include=["metadatas", "documents", "embeddings"])
# Out:
# {'ids': ['276d26b6-4604-48fc-bdde-fba38fb07970',
#   'f2e154d8-5b92-4381-9141-51b2ba6361f8',
#   '0b7d9b48-82b5-4fcc-b307-ec43ff2a03d8',
#   'dbb0e882-ce85-4489-999e-cb2e1e416fb8',
#   '95b3b8cc-010b-4e45-a276-6989290d2903',
#   '20d90905-a1e9-49b9-80d2-b189c39410ba',
#   'fa02260c-b111-40df-a613-a3822dc40423',
#   '70f64bd0-a763-43a4-ba4a-e591aed70aeb',
#   '4eb0e6b0-1690-4896-86ff-cdda95969989',
#   'e722182c-a5fd-4543-b719-80acc46e444f'],
#  'embeddings': array([[-0.01456909, -0.01055943,  0.02247441, ..., -0.00992599,
#           0.00923554, -0.00790532],
#         [-0.01855437,  0.00476378, -0.009264  , ..., -0.02157209,
#           0.00710284,  0.00119671],
#         [-0.01377398,  0.00108009,  0.00200977, ..., -0.01492608,
#           0.01358196, -0.01201383],
#         ...,
#         [-0.01407709, -0.00359821, -0.0012005 , ..., -0.0081305 ,
#           0.01522167,  0.00804499],
#         [-0.01041185,  0.00083084, -0.00820288, ..., -0.01259445,
#          -0.00714784, -0.00400912],
#         [-0.03533101, -0.00546049, -0.00637959, ...,  0.00366961,
#           0.00422039, -0.00734599]]),
#  'documents': ['Virat Kohli',
#   'MS Dhoni',
#   'Rohit Sharma',
#   'Jasprit Bumrah',
#   'Ravindra Jadeja',
#   'AB de Villiers',
#   'David Warner',
#   'Kane Williamson',
#   'Ben Stokes',
#   'Jos Buttler'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [{'team': 'RCB', 'role': 'Batsman'},
#   {'role': 'Wicketkeeper', 'team': 'CSK'},
#   {'role': 'Batsman', 'team': 'MI'},
#   {'team': 'MI', 'role': 'Bowler'},
#   {'role': 'All-rounder', 'team': 'CSK'},
#   {'role': 'Batsman', 'team': 'RCB'},
#   {'role': 'Batsman', 'team': 'SRH'},
#   {'role': 'Batsman', 'team': 'SRH'},
#   {'role': 'All-rounder', 'team': 'RR'},
#   {'team': 'RR', 'role': 'Wicketkeeper'}]}

# %%
vector_store.similarity_search("who is a bowler", k=3)
# Out:
# [Document(metadata={'role': 'All-rounder', 'team': 'RR'}, page_content='Ben Stokes'),
#  Document(metadata={'team': 'MI', 'role': 'Bowler'}, page_content='Jasprit Bumrah'),
#  Document(metadata={'role': 'Batsman', 'team': 'SRH'}, page_content='David Warner')]

# %%
vector_store.similarity_search_with_score(query="", filter= {"team": "MI"})
# Out:
# [(Document(metadata={'role': 'Bowler', 'team': 'MI'}, page_content='Jasprit Bumrah'),
#   0.6036392450332642),
#  (Document(metadata={'team': 'MI', 'role': 'Batsman'}, page_content='Rohit Sharma'),
#   0.6043736934661865)]

# %%
updated_doc1 = Document(page_content="Virat Kohli is the best batsman in thw world", metadata={"team": "RCB", "role": "Batsman", "age": 34})

# %%
vector_store.update_document(document_id = '276d26b6-4604-48fc-bdde-fba38fb07970',document=updated_doc1)

# %%
vector_store.get(include=["metadatas", "documents", "embeddings"])
# Out:
# {'ids': ['276d26b6-4604-48fc-bdde-fba38fb07970',
#   'f2e154d8-5b92-4381-9141-51b2ba6361f8',
#   '0b7d9b48-82b5-4fcc-b307-ec43ff2a03d8',
#   'dbb0e882-ce85-4489-999e-cb2e1e416fb8',
#   '95b3b8cc-010b-4e45-a276-6989290d2903',
#   '20d90905-a1e9-49b9-80d2-b189c39410ba',
#   'fa02260c-b111-40df-a613-a3822dc40423',
#   '70f64bd0-a763-43a4-ba4a-e591aed70aeb',
#   '4eb0e6b0-1690-4896-86ff-cdda95969989',
#   'e722182c-a5fd-4543-b719-80acc46e444f'],
#  'embeddings': array([[-0.00079955,  0.00703137,  0.02337117, ..., -0.00937724,
#           0.00113149, -0.01079102],
#         [-0.01855437,  0.00476378, -0.009264  , ..., -0.02157209,
#           0.00710284,  0.00119671],
#         [-0.01377398,  0.00108009,  0.00200977, ..., -0.01492608,
#           0.01358196, -0.01201383],
#         ...,
#         [-0.01407709, -0.00359821, -0.0012005 , ..., -0.0081305 ,
#           0.01522167,  0.00804499],
#         [-0.01041185,  0.00083084, -0.00820288, ..., -0.01259445,
#          -0.00714784, -0.00400912],
#         [-0.03533101, -0.00546049, -0.00637959, ...,  0.00366961,
#           0.00422039, -0.00734599]]),
#  'documents': ['Virat Kohli is the best batsman in thw world',
#   'MS Dhoni',
#   'Rohit Sharma',
#   'Jasprit Bumrah',
#   'Ravindra Jadeja',
#   'AB de Villiers',
#   'David Warner',
#   'Kane Williamson',
#   'Ben Stokes',
#   'Jos Buttler'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [{'team': 'RCB', 'age': 34, 'role': 'Batsman'},
#   {'role': 'Wicketkeeper', 'team': 'CSK'},
#   {'team': 'MI', 'role': 'Batsman'},
#   {'team': 'MI', 'role': 'Bowler'},
#   {'team': 'CSK', 'role': 'All-rounder'},
#   {'role': 'Batsman', 'team': 'RCB'},
#   {'team': 'SRH', 'role': 'Batsman'},
#   {'team': 'SRH', 'role': 'Batsman'},
#   {'role': 'All-rounder', 'team': 'RR'},
#   {'role': 'Wicketkeeper', 'team': 'RR'}]}

# %%
vector_store.delete(ids = ['276d26b6-4604-48fc-bdde-fba38fb07970'])

# %%
vector_store.get(include=["metadatas", "documents", "embeddings"])
# Out:
# {'ids': ['f2e154d8-5b92-4381-9141-51b2ba6361f8',
#   '0b7d9b48-82b5-4fcc-b307-ec43ff2a03d8',
#   'dbb0e882-ce85-4489-999e-cb2e1e416fb8',
#   '95b3b8cc-010b-4e45-a276-6989290d2903',
#   '20d90905-a1e9-49b9-80d2-b189c39410ba',
#   'fa02260c-b111-40df-a613-a3822dc40423',
#   '70f64bd0-a763-43a4-ba4a-e591aed70aeb',
#   '4eb0e6b0-1690-4896-86ff-cdda95969989',
#   'e722182c-a5fd-4543-b719-80acc46e444f'],
#  'embeddings': array([[-0.01855437,  0.00476378, -0.009264  , ..., -0.02157209,
#           0.00710284,  0.00119671],
#         [-0.01377398,  0.00108009,  0.00200977, ..., -0.01492608,
#           0.01358196, -0.01201383],
#         [-0.03059122,  0.01082909,  0.02247258, ..., -0.02781714,
#           0.00993197, -0.01889682],
#         ...,
#         [-0.01407709, -0.00359821, -0.0012005 , ..., -0.0081305 ,
#           0.01522167,  0.00804499],
#         [-0.01041185,  0.00083084, -0.00820288, ..., -0.01259445,
#          -0.00714784, -0.00400912],
#         [-0.03533101, -0.00546049, -0.00637959, ...,  0.00366961,
#           0.00422039, -0.00734599]]),
#  'documents': ['MS Dhoni',
#   'Rohit Sharma',
#   'Jasprit Bumrah',
#   'Ravindra Jadeja',
#   'AB de Villiers',
#   'David Warner',
#   'Kane Williamson',
#   'Ben Stokes',
#   'Jos Buttler'],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'embeddings'],
#  'data': None,
#  'metadatas': [{'role': 'Wicketkeeper', 'team': 'CSK'},
#   {'team': 'MI', 'role': 'Batsman'},
#   {'role': 'Bowler', 'team': 'MI'},
#   {'role': 'All-rounder', 'team': 'CSK'},
#   {'role': 'Batsman', 'team': 'RCB'},
#   {'team': 'SRH', 'role': 'Batsman'},
#   {'role': 'Batsman', 'team': 'SRH'},
#   {'role': 'All-rounder', 'team': 'RR'},
#   {'role': 'Wicketkeeper', 'team': 'RR'}]}
